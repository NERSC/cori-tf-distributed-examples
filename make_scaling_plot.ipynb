# %%
num_iterations = [519,1026, 2108, 3939, 8087, 16622, 30381, 50403, 50688] #64

num_examples = [k*128 for k in num_iterations]

examples_per_second = [n / (10*60.) for n in num_examples]

more_ex = [n / num_examples[0] for n in num_examples]

node_cnts = [2**i for i in range(9)]

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# %matplotlib inline

plt.plot(node_cnts, examples_per_second, "-o")
plt.xlabel("Number of Nodes")
plt.ylabel("Examples Per Second")
plt.title("TensorFlow on Cori Scaling")

# %%
60000 / 256.
# Out:
# 234.375
